# %%
import numpy as np
import csv
from numpy import matrix as mt

# emmisivity, refl, trans  csv data transferred into matrix 
e_arr=np.array(list(csv.reader(open("repository/repo/TER_file_cryorun7_emiss.csv","rb"),delimiter=','))).astype('float')
p_arr=np.array(list(csv.reader(open("repository/repo/TER_file_cryorun7_refl.csv","rb"),delimiter=','))).astype('float')
t_arr=np.array(list(csv.reader(open("repository/repo/TER_file_cryorun7_trans.csv","rb"),delimiter=','))).astype('float')

N= 6000

#def planck(k, T):
    #if (h*c*k/(s*T)) < 10**(-4):
        #I = 2.*h*c*(k**3)*(s*T)/(h*c*k)
    #elif (h*c*k/(s*T)) > 10**(4):
       # I = 0.
    #else:
        #I = 2.*h*c*(k**3)/(np.exp(h*c*k/(s*T))-1)
   # return I

ei=0.
p=0.
t=0.
for i in np.arange(0,N):
    ei+=e_arr[i,2]
    p+=p_arr[i,2]
    t+=t_arr[i,2]
    
    
avg_ei=ei/N
avg_p=p/N
avg_t=t/N

print 'average of emissivity of 3rd element:', avg_ei
print 'average of reflectivity of 3rd element:', avg_p
print 'average of transmittivity of 3rd element:', avg_t
print
print 'sum of averages of emissivity, reflectivity and transmittivity of the 3rd element:', avg_ei+avg_p+avg_t

print 
print
print '******'
print 
print
ei=0.
p=0.
t=0.
for i in np.arange(0,N):
    ei+=e_arr[i,3]
    p+=p_arr[i,3]
    t+=t_arr[i,3]
    
    
avg_ei=ei/N
avg_p=p/N
avg_t=t/N

print 'average of emissivity of 4th element:', avg_ei
print 'average of reflectivity of 4th element:', avg_p
print 'average of transmittivity of 4th element:', avg_t
print
print
print 'sum of averages of emissivity, reflectivity and transmittivity of the 4th element:', avg_ei+avg_p+avg_t

print 
print
print '******'
print 
print
ei=0.
p=0.
t=0.
for i in np.arange(0,N):
    ei+=e_arr[i,12]
    p+=p_arr[i,12]
    t+=t_arr[i,12]
    
    
avg_ei=ei/N
avg_p=p/N
avg_t=t/N

print 'average of emissivity of 13th element:', avg_ei
print 'average of reflectivity of 13th element:', avg_p
print 'average of transmittivity of 13th element:', avg_t
print
print
print 'sum of averages of emissivity, reflectivity and transmittivity of the 13th element:', avg_ei+avg_p+avg_t

print 
print
print '******'
print 
print
ei=0.
p=0.
t=0.
for i in np.arange(0,N):
    ei+=e_arr[i,9]
    p+=p_arr[i,9]
    t+=t_arr[i,9]
    
    
avg_ei=ei/N
avg_p=p/N
avg_t=t/N

print 'average of emissivity of 8th element:', avg_ei
print 'average of reflectivity of 8th element:', avg_p
print 'average of transmittivity of 8th element:', avg_t
print
print
print 'sum of averages of emissivity, reflectivity and transmittivity of the 8th element:', avg_ei+avg_p+avg_t
# Out:
# average of emissivity of 3rd element: 0.0085500841391
# average of reflectivity of 3rd element: 0.727441185238
# average of transmittivity of 3rd element: 0.26400889041
#
# sum of averages of emissivity, reflectivity and transmittivity of the 3rd element: 1.00000015979
#
#
# ******
#
#
# average of emissivity of 4th element: 0.0085500841391
# average of reflectivity of 4th element: 0.790837040878
# average of transmittivity of 4th element: 0.200612874983
#
#
# sum of averages of emissivity, reflectivity and transmittivity of the 4th element: 1.0
#
#
# ******
#
#
# average of emissivity of 13th element: 1.0
# average of reflectivity of 13th element: 0.0
# average of transmittivity of 13th element: 0.0
#
#
# sum of averages of emissivity, reflectivity and transmittivity of the 13th element: 1.0
#
#
# ******
#
#
# average of emissivity of 8th element: 0.993260069331
# average of reflectivity of 8th element: 3.49014313098e-11
# average of transmittivity of 8th element: 0.00673993067389
# ...
